# %% [markdown]
# # hello world of computer vision mnist

# %%
import numpy as  np
import matplotlib.pyplot as plt
from keras.datasets import mnist
import random
import seaborn as sns
# Out:
# Using TensorFlow backend.

# %%
(xtr,ytr),(xts,yts) = mnist.load_data()

# %%
y_true = yts

# %%
#plt.imshow(xtr[0])
#plt.title(ytr[0])
#plt.show()

# %%
print('xtr shape',xtr.shape,sep=':')
print('ytr shape',ytr.shape,sep=':')
# Out:
# xtr shape:(60000, 28, 28)
# ytr shape:(60000,)

# %%
n_cols = 5
n_classes = 10

fig , axes = plt.subplots(nrows=n_classes,ncols=n_cols,figsize=(5,10))
fig.tight_layout()

for i in range(n_cols) :
    for j in range(n_classes):
        images = xtr[ytr==j]
        selected_image = images[random.randint(0,(len(images)-1)),:,:]
        axes[j][i].imshow(selected_image,cmap='gray')
        axes[j][i].axis('off')
        if i == 2 :
            axes[j][i].set_title(str(j))

# %%
sns.countplot(ytr)
plt.show()

# %% [markdown]
# #  Image Augmentation
# <br>
# creating new images from existing images
# <br>
# by distorting them (adding noise , rotate , zoom in zoom out etc)

# %% [markdown]
# # Pre - processing

# %%
n_pixels = xtr.shape[1]*xtr.shape[2]
xtr = xtr.reshape(xtr.shape[0],n_pixels)
xtr = xtr/255 # brings value b/w 0 and 1
xts = xts.reshape(xts.shape[0],n_pixels)
xts = xts/255

# %% [markdown]
# # onehotEncoding ytr array

# %%
from keras.utils.np_utils import to_categorical
ytr = to_categorical(ytr,10)
yts = to_categorical(yts,10)

# %%
# Out:
# (60000, 10)

# %% [markdown]
# # creating neural model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
def create_model() :
    model = Sequential()
    model.add(Dense(32,input_dim=n_pixels,activation = 'relu'))
    model.add(Dense(64,input_dim=n_pixels,activation = 'relu'))
    model.add(Dense(10,activation='softmax')) # activation for 
    model.compile(Adam(lr=0.01),loss ='categorical_crossentropy', metrics = ['accuracy'])
    return model

model = create_model()
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
h = model.fit(xtr,ytr,epochs=10,verbose=1,validation_data=(xts,yts))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.2914 - accuracy: 0.9135 - val_loss: 0.1966 - val_accuracy: 0.9440
# Epoch 2/10
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.2095 - accuracy: 0.9406 - val_loss: 0.1951 - val_accuracy: 0.9473
# Epoch 3/10
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1923 - accuracy: 0.9475 - val_loss: 0.1917 - val_accuracy: 0.9484
# Epoch 4/10
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1756 - accuracy: 0.9517 - val_loss: 0.1721 - val_accuracy: 0.9532
# Epoch 5/10
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.1645 - accuracy: 0.9546 - val_loss: 0.1894 - val_accuracy: 0.9532
# Epoch 6/10
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1607 - accuracy: 0.9566 - val_loss: 0.2324 - val_accuracy: 0.9406
# Epoch 7/10
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1477 - accuracy: 0.9595 - val_loss: 0.1780 - val_accuracy: 0.9558
# Epoch 8/10
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1469 - accuracy: 0.9606 - val_loss: 0.2340 - val_accuracy: 0.9484
# Epoch 9/10
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1409 - accuracy: 0.9623 - val_loss: 0.2135 - val_accuracy: 0.9519
# Epoch 10/10
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1414 - accuracy: 0.9617 - val_loss: 0.1805 - val_accuracy: 0.9550

# %%
# to save the model trained in .h5 using tensorflow
model.save('model.h5')

# %% [markdown]
# #  Predicting images

# %%
import cv2
img = cv2.imread(r"D:\Datasets\digit.png")

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img = cv2.resize(img,(28,28))
plt.imshow(img,cmap='gray')
plt.show()

# %%
img = img.reshape(1,n_pixels)
img = img/255
model.predict_classes(img)
# Out:
# array([7], dtype=int64)

# %% [markdown]
# # to download file from colab <br>
# model.save('ddjdj.h5')<br>
# from google colab import filer<br>
# filer.download('ddjdj.h5')

# %% [markdown]
# #  Image Augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(rotation_range=10,zoom_range=0.1,shear_range=0.1,width_shift_range=0.1,height_shift_range=0.1,brightness_range=(0.1,1))

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict_classes(xts)
print(confusion_matrix(y_true,y_pred))
# Out:
# [[ 957    0    4    0    1    1    2    2   13    0]
#  [   0 1126    0    1    0    0    1    2    5    0]
#  [   1   10  989    7    2    0    1    8   13    1]
#  [   0   13   21  902    1   43    0    6   13   11]
#  [   0    0    3    0  943    0    8    2    2   24]
#  [   3    0    1    8    1  847    3    7   18    4]
#  [   7    3    7    0    8    8  915    0   10    0]
#  [   5    3    9    7    4    0    0  988    4    8]
#  [   3    1    7    7    3    9    0    6  927   11]
#  [   2    2    1    8   17    5    1   10    7  956]]
