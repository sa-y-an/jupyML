# %% [markdown]
# # hello world of computer vision mnist

# %%
import numpy as  np
import matplotlib.pyplot as plt
from keras.datasets import mnist
import random
import seaborn as sns
# Out:
# Using TensorFlow backend.

# %%
(xtr,ytr),(xts,yts) = mnist.load_data()

# %%
#plt.imshow(xtr[0])
#plt.title(ytr[0])
#plt.show()

# %%
print('xtr shape',xtr.shape,sep=':')
print('ytr shape',ytr.shape,sep=':')
# Out:
# xtr shape:(60000, 28, 28)
# ytr shape:(60000,)

# %%
n_cols = 5
n_classes = 10

fig , axes = plt.subplots(nrows=n_classes,ncols=n_cols,figsize=(5,10))
fig.tight_layout()

for i in range(n_cols) :
    for j in range(n_classes):
        images = xtr[ytr==j]
        selected_image = images[random.randint(0,(len(images)-1)),:,:]
        axes[j][i].imshow(selected_image,cmap='gray')
        axes[j][i].axis('off')
        if i == 2 :
            axes[j][i].set_title(str(j))

# %%
sns.countplot(ytr)
plt.show()

# %% [markdown]
# #  Image Augmentation
# <br>
# creating new images from existing images
# <br>
# by distorting them (adding noise , rotate , zoom in zoom out etc)

# %% [markdown]
# # Pre - processing

# %%
n_pixels = xtr.shape[1]*xtr.shape[2]
xtr = xtr.reshape(xtr.shape[0],n_pixels)
xtr = xtr/255 # brings value b/w 0 and 1
xts = xts.reshape(xts.shape[0],n_pixels)
xts = xts/255

# %% [markdown]
# # onehotEncoding ytr array

# %%
from keras.utils.np_utils import to_categorical
ytr = to_categorical(ytr,10)
yts = to_categorical(yts,10)

# %%
ytr.shape
# Out:
# (60000, 10)

# %% [markdown]
# # creating neural model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
def create_model() :
    model = Sequential()
    model.add(Dense(32,input_dim=n_pixels,activation = 'relu'))
    model.add(Dense(64,input_dim=n_pixels,activation = 'relu'))
    model.add(Dense(10,activation='softmax')) # activation for 
    model.compile(Adam(lr=0.01),loss ='categorical_crossentropy', metrics = ['accuracy'])
    return model

model = create_model()
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
h = model.fit(xtr,ytr,epochs=10,verbose=1,validation_data=(xts,yts))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.2942 - accuracy: 0.9136 - val_loss: 0.2231 - val_accuracy: 0.9374
# Epoch 2/10
# 60000/60000 [==============================] - 6s 102us/step - loss: 0.2021 - accuracy: 0.9422 - val_loss: 0.2126 - val_accuracy: 0.9429
# Epoch 3/10
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.1850 - accuracy: 0.9494 - val_loss: 0.2245 - val_accuracy: 0.9417
# Epoch 4/10
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1718 - accuracy: 0.9518 - val_loss: 0.2262 - val_accuracy: 0.9444
# Epoch 5/10
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.1626 - accuracy: 0.9556 - val_loss: 0.1791 - val_accuracy: 0.9537
# Epoch 6/10
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1571 - accuracy: 0.9573 - val_loss: 0.1924 - val_accuracy: 0.9511
# Epoch 7/10
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.1525 - accuracy: 0.9587 - val_loss: 0.2326 - val_accuracy: 0.9429
# Epoch 8/10
# 60000/60000 [==============================] - 6s 100us/step - loss: 0.1479 - accuracy: 0.9599 - val_loss: 0.1844 - val_accuracy: 0.9566
# Epoch 9/10
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1430 - accuracy: 0.9606 - val_loss: 0.2049 - val_accuracy: 0.9555
# Epoch 10/10
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.1395 - accuracy: 0.9624 - val_loss: 0.2097 - val_accuracy: 0.9567

# %%
# to save the model trained in .h5 using tensorflow
model.save('model.h5')

# %% [markdown]
# #  Predicting images

# %%
import cv2
img = cv2.imread(r"D:\Datasets\digit.png")

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img = cv2.resize(img,(28,28))
plt.imshow(img,cmap='gray')
plt.show()

# %%
img = img.reshape(1,n_pixels)
img = img/255
model.predict_classes(img)
# Out:
# array([3], dtype=int64)

# %% [markdown]
# # to download file from colab <br>
# model.save('ddjdj.h5')<br>
# from google colab import filer<br>
# filer.download('ddjdj.h5')

# %% [markdown]
# #  Image Augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(rotation_range=10,zoom_range=0.1,shear_range=0.1,width_shift_range=0.1,height_shift_range=0.1,brightness_range=(0.1,1))

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict_classes(xts)
